# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pytextbook/pytextbook/blob/main/6.1.%20국민청원%20분석%20및%20시각화.ipynb)
#
#
# # 국민청원 데이터 분석하기

# %%
# 출력데이터를 깔끔하게 표시하기 위해
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install plotnine
# Out:
# Requirement already satisfied: plotnine in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (0.8.0)
# Requirement already satisfied: mizani>=0.7.3 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from plotnine) (0.7.3)
# Requirement already satisfied: statsmodels>=0.12.1 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from plotnine) (0.13.2)
# Requirement already satisfied: patsy>=0.5.1 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: descartes>=1.1.0 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from plotnine) (1.1.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from plotnine) (1.21.6)
# Requirement already satisfied: matplotlib>=3.1.1 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from plotnine) (3.5.3)
# Requirement already satisfied: scipy>=1.5.0 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from plotnine) (1.7.3)
# Requirement already satisfied: pandas>=1.1.0 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from plotnine) (1.3.5)
# Requirement already satisfied: packaging>=20.0 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.1->plotnine) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.1->plotnine) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.1->plotnine) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.1->plotnine) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.1->plotnine) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.1->plotnine) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.1->plotnine) (0.11.0)
# Requirement already satisfied: palettable in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from mizani>=0.7.3->plotnine) (3.3.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.1.0->plotnine) (2022.4)
# Requirement already satisfied: six in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Requirement already satisfied: typing-extensions in /Users/corazzon/opt/anaconda3/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=3.1.1->plotnine) (4.3.0)

# %%
import os
import platform
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %% [markdown]
# 여기에서는 시각화 도구로 [plotnine(A grammar of graphics for Python)](https://github.com/has2k1/plotnine)을 사용한다.

# %%
from plotnine import *

# %% [markdown]
# # Pandas로 데이터 살펴보기
# * 데이터 출처 : https://github.com/akngs/petitions

# %%
base_path = "data"
file_name = "petition.csv"

def file_exist_check(base_path, file_name):
    if os.path.exists(f"./{base_path}/{file_name}"):
        print(f"{os.getcwd()}/{base_path} 경로에 파일이 있음")
        return

    if not os.path.exists(base_path):
        os.makedirs(base_path)
    
    if platform.system() == "Linux":
        # 구글 드라이브에서 csv 파일을 읽어오기 위해 gauth 인증하기
        # !pip install -U -q PyDrive
        from pydrive.auth import GoogleAuth
        from pydrive.drive import GoogleDrive
        from google.colab import auth
        from oauth2client.client import GoogleCredentials
        
        auth.authenticate_user()
        gauth = GoogleAuth()
        gauth.credentials = GoogleCredentials.get_application_default()
        drive = GoogleDrive(gauth)
        url ='https://drive.google.com/open?id=1d8VEAj6n83wT1YRlCrhoU_1mMSvYpXc4'

        id = url.split('=')[1]
        downloaded = drive.CreateFile({'id':id}) 
        downloaded.GetContentFile(f'{base_path}/{file_name}')  
        print(f"사용자의 구글 드라이브에 {base_path}/{file_name} 다운로드 완료")
        return 
    else:
        print(f"{file_link} 에서 다운로드 받아 실습 경로 {os.getcwd()}/{base_path}에 옮겨주세요.""")
        return
    
file_exist_check(base_path, file_name)
# Out:
# /Users/corazzon/codes/pytextbook/data 경로에 파일이 있음

# %%
petitions = pd.read_csv(f"{base_path}/petition.csv", index_col="article_id",
                        parse_dates=['start', 'end'])
# 데이터의 행과 열의 수 확인
petitions.shape
# Out:
# (377756, 7)

# %% [markdown]
# ## 일부 데이터 미리보기

# %%
# head를 통해 상위 몇 개의 데이터만을 본다.
# 기본은 5개를 불러오며, 괄호안에 숫자를 적어주면 숫자만큼 불러온다.
petitions.head(3)
# Out:
#                 start        end  answered  votes category  \
# article_id
# 21         2017-08-19 2017-11-17         0      9    안전/환경
# 22         2017-08-19 2017-11-17         0     17       기타
# 23         2017-08-19 2017-09-03         0      0       미래
#
#                           title  \
# article_id
# 21          스텔라 데이지호에 대한 제안입니다.
# 22               비리제보처를 만들어주세요.
# 23                     제2의 개성공단
#
#                                                       content
# article_id
# 21          스텔라 데이지호에 대한 제안입니다.\n3월31일 스텔라 데이지호가 침몰하고 5달째가...
# 22          현 정부에 국민들이 가장 원하는 것은 부패척결입니다.  우리 사회에 각종 비리들이 ...
# 23          만일 하시는 대통령님 및 각 부처 장관님,주무관님들 안녕하세요!!\n전남 목포에서 ...

# %%
# 위에서 불러온 head와 반대로 뒤에서부터 데이터를 읽어온다.
# 터미널에서 크롤링을 하며 tail 파일명으로 크롤링 데이터를 읽었던 기억을 떠올려 보자.
petitions.tail(3)
# Out:
#                 start        end  answered  votes  category  \
# article_id
# 492041     2019-01-09 2019-02-08         0      1  외교/통일/국방
# 492042     2019-01-09 2019-02-08         0      4      정치개혁
# 492043     2019-01-09 2019-02-08         0      1        행정
#
#                                                  title  \
# article_id
# 492041                                남한땅에 옥류관을 오픈해주세요
# 492042                                임종석실장님 수고많으셨습니다.
# 492043      예천군과 환경부를 규탄합니다. 어불성설인 가축사육 관련 법규를 개정해주세요!
#
#                                                       content
# article_id
# 492041      말그대로 옥류관을 여기서 열면 진짜 재미있고 신나는 일이 일어날것 같은 느낌이 듭니...
# 492042      범죄정권이후 많은 어려움을 갖고 시작한 국민의정부.\n저급한 자칭 보수단체와 한국당...
# 492043      해당 사건이 발생한 곳은 요즘은 매체에서 매일 나오는 곳으로 '군의원의 외유성 해외...

# %%
# 데이터프레임의 컬럼만을 불러올 수 있다.
petitions.columns
# Out:
# Index(['start', 'end', 'answered', 'votes', 'category', 'title', 'content'], dtype='object')

# %%
# 데이터셋의 정보를 볼 수 있다.
# 어떤 컬럼이 있고 몇 개의 데이터가 있으며 어떤 타입인지 볼 수 있다.
petitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 377756 entries, 21 to 492043
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   start     377756 non-null  datetime64[ns]
#  1   end       377756 non-null  datetime64[ns]
#  2   answered  377756 non-null  int64
#  3   votes     377756 non-null  int64
#  4   category  377756 non-null  object
#  5   title     377756 non-null  object
#  6   content   377755 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 23.1+ MB

# %%
# petitions.describe?

# %%
# 숫자로 된 데이터에 대해 count, mean, std, min, max값 등을 볼 수 있다.
petitions.describe()
# Out:
#             answered         votes
# count  377756.000000  3.777560e+05
# mean        0.000077  1.514069e+02
# std         0.008761  4.842551e+03
# min         0.000000  0.000000e+00
# 25%         0.000000  1.000000e+00
# 50%         0.000000  5.000000e+00
# 75%         0.000000  1.500000e+01
# max         1.000000  1.192049e+06

# %% [markdown]
# ## 결측치가 있는지 확인

# %%
petitions.isnull().sum()
# Out:
# start       0
# end         0
# answered    0
# votes       0
# category    0
# title       0
# content     1
# dtype: int64

# %% [markdown]
# ### 답변대상 청원 컬럼 다시 만들기
# 기존 `answerd`컬럼은 답변 여부가 있었다.
# 여기에서는 답변 받은 것과 상관없이 답변 대상 건에 대해 새로운 컬럼을 추가해 주었다.

# %%
(petitions['votes'] > 200000) == 1
# Out:
# article_id
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
#           ...
# 492039    False
# 492040    False
# 492041    False
# 492042    False
# 492043    False
# Name: votes, Length: 377756, dtype: bool

# %%
petitions['answer'] = (petitions['votes'] > 200000) == 1
petitions.shape
# Out:
# (377756, 8)

# %%
petitions.head(3)
# Out:
#                 start        end  answered  votes category  \
# article_id
# 21         2017-08-19 2017-11-17         0      9    안전/환경
# 22         2017-08-19 2017-11-17         0     17       기타
# 23         2017-08-19 2017-09-03         0      0       미래
#
#                           title  \
# article_id
# 21          스텔라 데이지호에 대한 제안입니다.
# 22               비리제보처를 만들어주세요.
# 23                     제2의 개성공단
#
#                                                       content  answer
# article_id
# 21          스텔라 데이지호에 대한 제안입니다.\n3월31일 스텔라 데이지호가 침몰하고 5달째가...   False
# 22          현 정부에 국민들이 가장 원하는 것은 부패척결입니다.  우리 사회에 각종 비리들이 ...   False
# 23          만일 하시는 대통령님 및 각 부처 장관님,주무관님들 안녕하세요!!\n전남 목포에서 ...   False

# %%
petitions.tail()
# Out:
#                 start        end  answered  votes  category  \
# article_id
# 492039     2019-01-09 2019-02-08         0     48    인권/성평등
# 492040     2019-01-09 2019-02-08         0      5      정치개혁
# 492041     2019-01-09 2019-02-08         0      1  외교/통일/국방
# 492042     2019-01-09 2019-02-08         0      4      정치개혁
# 492043     2019-01-09 2019-02-08         0      1        행정
#
#                                                         title  \
# article_id
# 492039                          박종철 의원. 폭행구속수사 및 의원직 박탈 청원합니다
# 492040      각 정상들은 들으시요 국회의원을 학력과 무관한 양심 및  윤리가 있는  서민이 되어...
# 492041                                       남한땅에 옥류관을 오픈해주세요
# 492042                                       임종석실장님 수고많으셨습니다.
# 492043             예천군과 환경부를 규탄합니다. 어불성설인 가축사육 관련 법규를 개정해주세요!
#
#                                                       content  answer
# article_id
# 492039      나라돈으로 해외연수가서 현지 동반 가이드를 때려 안경 파편이 얼굴이 꽂혔답니다. C...   False
# 492040      각 정당은 현재 국회의원 개개인을 심사하면 지탄받은 사람이 국\n회를 장악하고 있습...   False
# 492041      말그대로 옥류관을 여기서 열면 진짜 재미있고 신나는 일이 일어날것 같은 느낌이 듭니...   False
# 492042      범죄정권이후 많은 어려움을 갖고 시작한 국민의정부.\n저급한 자칭 보수단체와 한국당...   False
# 492043      해당 사건이 발생한 곳은 요즘은 매체에서 매일 나오는 곳으로 '군의원의 외유성 해외...   False

# %% [markdown]
# ### 청원기간 컬럼 생성

# %%
petitions['duration'] = petitions['end'] - petitions['start']
petitions.sort_values('duration', ascending=True).head(3)
# Out:
#                 start        end  answered  votes category  \
# article_id
# 13577      2017-09-12 2017-09-19         0     20    육아/교육
# 4213       2017-09-05 2017-09-12         0      1   인권/성평등
# 4214       2017-09-05 2017-09-12         0      0     정치개혁
#
#                              title  \
# article_id
# 13577           사립유치원의 집단휴업을 반대합니다
# 4213        청소년 보호법이 아니라 소년법입니다...
# 4214                        소년법 강화
#
#                                                       content  answer duration
# article_id
# 13577       국공립 유치원도 없고 국공립어린이집 들어가기도 힘든 실정에 사립유치원은 부모들의 어...   False   7 days
# 4213                                             소년법 폐지 청원합니다   False   7 days
# 4214        이번 부산여중생 사건을보고 느낍니다.\n소년법 폐지해주셨으면 좋겠습니다.\n아님 강...   False   7 days

# %% [markdown]
# ### 청원기간별 건

# %%
petitions['duration'].value_counts()
# Out:
# 30 days    366556
# 90 days      6754
# 7 days       2436
# 15 days      1204
# 60 days       806
# Name: duration, dtype: int64

# %% [markdown]
# #### 청원기간이 90일이고 답변 대상 건

# %%
petitions[(petitions['duration'] == '90 days') & (petitions['answer'] == 1)]
# Out:
#                 start        end  answered   votes category     title  \
# article_id
# 10949      2017-09-06 2017-12-05         1  615354       미래  조두순 출소반대
#
#                                   content  answer duration
# article_id
# 10949       제발 조두순 재심다시해서 무기징역으로 해야됩니다!!!    True  90 days

# %% [markdown]
# #### 청원기간이 60일이고 답변 대상 건

# %%
petitions_60_answer = petitions[(petitions['duration'] == '60 days') & (petitions['answer'] == 1)]
print(petitions_60_answer.shape)
petitions_60_answer.head()
# Out:
# (1, 9)
#                 start        end  answered   votes category  \
# article_id
# 1785       2017-09-03 2017-11-02         1  296330   인권/성평등
#
#                                                         title  \
# article_id
# 1785        청소년이란 이유로 보호법을 악용하는 잔인무도한 청소년들이 늘어나고있습니다. 반드시 ...
#
#                                                       content  answer duration
# article_id
# 1785        안녕하십니까. 청소년보호법이란 명목하에 나쁜짓을 일삼는 청소년들이 너무나 많아지고 ...    True  60 days

# %% [markdown]
# #### 청원기간이 30일이고 답변 대상 건

# %%
petitions_30_answer = petitions[(petitions['duration'] == '30 days') \
                                    & (petitions['answer'] == 1)]
print(petitions_30_answer.shape)
petitions_30_answer.head()
# Out:
# (75, 9)
#                 start        end  answered   votes category  \
# article_id
# 18278      2017-09-30 2017-10-30         1  235372   인권/성평등
# 26024      2017-11-04 2017-12-04         1  216774    안전/환경
# 45581      2017-11-17 2017-12-17         1  281985     보건복지
# 49083      2017-11-24 2017-12-24         1  211064       기타
# 57132      2017-12-03 2018-01-02         1  255554     성장동력
#
#                                                     title  \
# article_id
# 18278             낙태죄 폐지와 자연유산 유도약(미프진) 합법화 및 도입을 부탁드립니다.
# 26024                 '주취감형(술을 먹으면 형벌 감형)' 폐지를 건의(청원)합니다.
# 45581               권역외상센터 (이국종 교수님) 추가적, 제도적, 환경적, 인력 지원
# 49083                전안법. 18살, 미성년자에게 정부가 직접 찍어주는 범죄자 낙인!
# 57132       전안법 합리적으로 개정 또는 폐지해주세요.(소상공인 소비자 모두 죽는법안입니다.)
#
#                                                       content  answer duration
# article_id
# 18278       안녕하세요. 존경하는 대통령님 의원님\n낙태죄 폐지를 청원합니다.\n현재 대한민국은...    True  30 days
# 26024       '주취감형'이란, 술을 먹고 범행을 저지를 때, 심신미약 (이성이 없고 우발적)이라...    True  30 days
# 45581       청원사항)\n중증외상분야의 추가적, 제도적, 환경적, 인력 지원 방안마련\n현 의료...    True  30 days
# 49083       3년 이하의 징역, 또는3천만원 이하의 벌금. 혹은 500만원 이하의 과태료.\n설...    True  30 days
# 57132       2017년 1월 28일부터 시행되는 법령으로 국가기술표준원에서 관리하는 전기제품에만...    True  30 days

# %% [markdown]
# #### 청원기간이 7일이고 답변 대상 건

# %%
petitions_7_answer = petitions[(petitions['duration'] == '7 days') \
                                   & (petitions['answer'] == 1)]
print(petitions_7_answer.shape)
petitions_7 = petitions[(petitions['duration'] == '7 days')]
print(petitions_7.shape)
petitions_7_count = petitions_7['start'].value_counts().reset_index()
petitions_7_count.columns = ['start', 'count']
petitions_7_count.sort_values('start', ascending=True)
# Out:
# (0, 9)
# (2436, 9)
#         start  count
# 25 2017-08-19      9
# 21 2017-08-20     18
# 17 2017-08-21     21
# 23 2017-08-22     15
# 16 2017-08-23     22
# 22 2017-08-24     18
# 18 2017-08-25     20
# 20 2017-08-26     19
# 24 2017-08-27     11
# 15 2017-08-28     24
# 14 2017-08-29     27
# 9  2017-08-30     40
# 12 2017-08-31     37
# 6  2017-09-01     52
# 10 2017-09-02     39
# 5  2017-09-03     53
# 2  2017-09-04    331
# 0  2017-09-05    942
# 1  2017-09-06    335
# 3  2017-09-07    129
# 4  2017-09-08     94
# 7  2017-09-09     43
# 13 2017-09-10     32
# 19 2017-09-11     20
# 8  2017-09-12     41
# 11 2017-09-13     37
# 26 2017-09-14      7

# %% [markdown]
# ## 어느 분야의 청원이 가장 많이 들어왔는지

# %%
category = pd.DataFrame(petitions['category'].value_counts()).reset_index()
category.columns = ['category', 'counts']
category
# Out:
#        category  counts
# 0          정치개혁   59020
# 1            기타   46449
# 2        인권/성평등   33738
# 3         안전/환경   29196
# 4      교통/건축/국토   26910
# 5      외교/통일/국방   25705
# 6         육아/교육   24861
# 7          보건복지   23608
# 8           일자리   22111
# 9            행정   19373
# 10  문화/예술/체육/언론   17257
# 11           미래   17190
# 12        경제민주화   16281
# 13         성장동력    6991
# 14         반려동물    3827
# 15    저출산/고령화대책    3461
# 16         농산어촌    1778

# %% [markdown]
# ## 청원이 얼마 동안 집계되었는지

# %%
start_df = pd.DataFrame(petitions['start'].value_counts()).reset_index()
start_df.columns = ['start', 'counts']
start_df = start_df.sort_values('counts', ascending=False)
print('청원 집계: {}일'.format(start_df.shape[0]))
start_df.head()
# Out:
# 청원 집계: 509일
#        start  counts
# 0 2017-11-11    9623
# 1 2017-09-05    5952
# 2 2018-01-11    3368
# 3 2018-02-06    2631
# 4 2017-11-09    2487

# %% [markdown]
# ## 피봇 테이블로 투표를 가장 많이 받은 분야 보기

# %%
# pd.pivot_table?

# %%
petitions_unique = pd.pivot_table(petitions, index=['category'], aggfunc=np.sum)
petitions_best = petitions_unique.sort_values(by='votes', ascending=False).reset_index()
petitions_best
# Out:
#        category  answer  answered     votes
# 0        인권/성평등      23         9  12225998
# 1         안전/환경      10         2   6512799
# 2          정치개혁       7         2   5686172
# 3            기타       7         1   4720310
# 4         육아/교육       3         1   4420589
# 5          보건복지       3         2   4269399
# 6   문화/예술/체육/언론       7         4   4086382
# 7      외교/통일/국방       4         1   3637926
# 8      교통/건축/국토       3         2   2834727
# 9          반려동물       4         0   2023905
# 10        경제민주화       2         1   1720766
# 11           행정       1         1   1665855
# 12           미래       1         1   1120174
# 13          일자리       0         0   1113973
# 14         성장동력       2         2    866240
# 15    저출산/고령화대책       0         0    174841
# 16         농산어촌       0         0    114822

# %% [markdown]
# ## 투표를 가장 많이 받은 날

# %%
petitions_start = pd.pivot_table(petitions, index=['start'], aggfunc=np.sum)
votes_df = petitions_start.sort_values(by='votes', ascending=False)
votes_df.loc[petitions_start['votes'] > 350000]
# Out:
#             answer  answered    votes
# start
# 2018-10-17       1         0  1300523
# 2018-10-31       2         0   827096
# 2018-06-13       1         0   786157
# 2018-10-18       2         0   721524
# 2018-02-19       1         1   701520
# 2018-11-09       2         0   672819
# 2018-07-22       1         0   672491
# 2017-09-06       1         1   648209
# 2018-06-24       2         0   628925
# 2018-10-04       2         1   626761
# 2018-02-23       2         2   608530
# 2018-05-18       1         0   574483
# 2018-05-11       1         1   556549
# 2018-05-25       2         0   514253
# 2018-11-14       1         0   469027
# 2018-06-17       2         0   468341
# 2018-07-03       1         0   467132
# 2018-04-17       1         1   446950
# 2018-05-02       1         0   445493
# 2018-10-02       1         1   437841
# 2017-09-03       1         1   433356
# 2018-06-14       1         1   403351
# 2018-01-20       1         1   399683
# 2017-11-17       1         1   393348
# 2017-11-24       1         1   392782
# 2018-12-07       1         0   387305
# 2018-03-24       1         0   385480
# 2018-09-06       1         0   383145
# 2018-03-03       1         1   380016
# 2018-01-15       1         1   376187
# 2018-04-16       1         0   369318
# 2018-01-25       1         1   364926
# 2019-01-07       1         0   352139

# %% [markdown]
# ## 청원을 많이 받은 날 VS 투표를 많이 받은 날

# %%
# 인덱스로 되어있는 start를 키로 사용하기 위해 
# index로 설정된 start를 컬럼으로 변경해주고 인덱스를 생성한다.
votes_df = votes_df.reset_index()
votes_df.head()
# Out:
#        start  answer  answered    votes
# 0 2018-10-17       1         0  1300523
# 1 2018-10-31       2         0   827096
# 2 2018-06-13       1         0   786157
# 3 2018-10-18       2         0   721524
# 4 2018-02-19       1         1   701520

# %%
hottest_day_df = start_df.merge(votes_df, on='start', how='left')
hottest_day_df.nlargest(5, "votes")
# Out:
#          start  counts  answer  answered    votes
# 113 2018-10-17     926       1         0  1300523
# 80  2018-10-31    1010       2         0   827096
# 365 2018-06-13     542       1         0   786157
# 73  2018-10-18    1032       2         0   721524
# 259 2018-02-19     698       1         1   701520

# %%
hottest_day_df.nlargest(5, "counts")
# Out:
#        start  counts  answer  answered  votes
# 0 2017-11-11    9623       0         0  85074
# 1 2017-09-05    5952       0         0  48808
# 2 2018-01-11    3368       0         0  44570
# 3 2018-02-06    2631       0         0  83038
# 4 2017-11-09    2487       0         0  34774

# %% [markdown]
# ## 답변 대상 청원
# - 20만건 이상의 투표를 받으면 답변을 받을 수 있는 청원이 된다.

# %%
answered_df = petitions.loc[petitions['votes'] > 200000]
print('답변 대상 청원: {}건'.format(answered_df.shape[0]))
# Out:
# 답변 대상 청원: 77건

# %%
answered_df.head()
# Out:
#                 start        end  answered   votes category  \
# article_id
# 1785       2017-09-03 2017-11-02         1  296330   인권/성평등
# 10949      2017-09-06 2017-12-05         1  615354       미래
# 18278      2017-09-30 2017-10-30         1  235372   인권/성평등
# 26024      2017-11-04 2017-12-04         1  216774    안전/환경
# 45581      2017-11-17 2017-12-17         1  281985     보건복지
#
#                                                         title  \
# article_id
# 1785        청소년이란 이유로 보호법을 악용하는 잔인무도한 청소년들이 늘어나고있습니다. 반드시 ...
# 10949                                                조두순 출소반대
# 18278                 낙태죄 폐지와 자연유산 유도약(미프진) 합법화 및 도입을 부탁드립니다.
# 26024                     '주취감형(술을 먹으면 형벌 감형)' 폐지를 건의(청원)합니다.
# 45581                   권역외상센터 (이국종 교수님) 추가적, 제도적, 환경적, 인력 지원
#
#                                                       content  answer duration
# article_id
# 1785        안녕하십니까. 청소년보호법이란 명목하에 나쁜짓을 일삼는 청소년들이 너무나 많아지고 ...    True  60 days
# 10949                           제발 조두순 재심다시해서 무기징역으로 해야됩니다!!!    True  90 days
# 18278       안녕하세요. 존경하는 대통령님 의원님\n낙태죄 폐지를 청원합니다.\n현재 대한민국은...    True  30 days
# 26024       '주취감형'이란, 술을 먹고 범행을 저지를 때, 심신미약 (이성이 없고 우발적)이라...    True  30 days
# 45581       청원사항)\n중증외상분야의 추가적, 제도적, 환경적, 인력 지원 방안마련\n현 의료...    True  30 days

# %% [markdown]
# ### 답변 대상 청원 중 투표를 가장 많이 받은 것

# %%
answered_df.sort_values('votes', ascending=False).head(10)
# Out:
#                 start        end  answered    votes     category  \
# article_id
# 408609     2018-10-17 2018-11-16         0  1192049        안전/환경
# 269548     2018-06-13 2018-07-13         0   714875     외교/통일/국방
# 10949      2017-09-06 2017-12-05         1   615354           미래
# 142600     2018-02-19 2018-03-21         1   614127  문화/예술/체육/언론
# 230552     2018-05-11 2018-06-10         1   419006       인권/성평등
# 426834     2018-10-31 2018-11-30         0   416093       인권/성평등
# 314584     2018-07-22 2018-08-21         0   413924        육아/교육
# 395955     2018-10-02 2018-11-01         1   406655     교통/건축/국토
# 437737     2018-11-09 2018-12-09         0   397079       인권/성평등
# 442093     2018-11-14 2018-12-14         0   365418       인권/성평등
#
#                                                         title  \
# article_id
# 408609                          강서구 피시방 살인 사건. 또 심신미약 피의자입니다.
# 269548      제주도 불법 난민 신청 문제에 따른 난민법, 무사증 입국, 난민신청허가 폐지/개헌 ...
# 10949                                                조두순 출소반대
# 142600               김보름, 박지우 선수의 자격박탈과 적폐 빙상연맹의 엄중 처벌을 청원합니다
# 230552                 여성도 대한민국 국민입니다. 성별 관계없는 국가의 보호를 요청합니다.
# 426834      132cm, 31kg의 왜소한 50대 여성이 180cm가 넘는 건장한 20세 남성에...
# 314584                             23개월 아기가 폭행에 장이 끊어져 죽었습니다.
# 395955                     음주운전 교통사고로 친구 인생이 박살났습니다. 제발 도와주세요
# 437737                             억울하게 떠나신 저의 아버지의 원한을 풀어주세요
# 442093                                               이수역 폭행사건
#
#                                                       content  answer duration
# article_id
# 408609      2018년 10월 14일 엊그제 일어난 강서구 피시방 살인사건에 대한 청원입니다.\...    True  30 days
# 269548      2012년 난민법 제정으로 인해 외국인은 한달 무비자로 입국할 수 있으나 난민신청자...    True  30 days
# 10949                           제발 조두순 재심다시해서 무기징역으로 해야됩니다!!!    True  90 days
# 142600      오늘 여자 단체전 팀추월에서 김보름, 박지우 선수는 팀전인데도 불구하고 개인의 영달...    True  30 days
# 230552      최근 홍대 누드크로키 모델의 불법촬영 사건이 있었습니다.\n사건은 굉장히 빠르게 처...    True  30 days
# 426834      http://m.news1.kr/articles/?3464603\n관련 기사입니다....    True  30 days
# 314584      고생하시는 청와대 관계자 및 대통령님.\n이 글을 꼭 한번만 읽어주세요.\n너무나 ...    True  30 days
# 395955      9월 25일 새벽 2시 25분 경, 부산 해운대구 미포 오거리에서 술에 만취한 운전...    True  30 days
# 437737      46일동안 눈 한번 뜨시지 못한 채 11월 6일 새벽 4시에 저의 아버지가 억울하게...    True  30 days
# 442093      11월 13일 새벽4시 경 이수역의 한 맥주집에서 남자 다섯명이 여성 두 명을 폭행...    True  30 days

# %% [markdown]
# ## 시각화
# ## [A Grammar of Graphics for Python — plotnine](http://plotnine.readthedocs.io/en/stable/index.html)
# * [tutorial](http://plotnine.readthedocs.io/en/stable/tutorials.html)
# * [ggplot2-cheatsheet](https://www.rstudio.com/wp-content/uploads/2015/03/ggplot2-cheatsheet.pdf)
# * 이미지 출처 : [A Comprehensive Guide to the Grammar of Graphics for Effective Visualization of Multi-dimensional…](https://towardsdatascience.com/a-comprehensive-guide-to-the-grammar-of-graphics-for-effective-visualization-of-multi-dimensional-1f92b4ed4149)
#
# <img src="https://cdn-images-1.medium.com/max/2000/1*mcLnnVdHNg-ikDbHJfHDNA.png">

# %%
# 카테고리별로 집계된 데이터를 barplot으로 그려본다.
# 그런데 한글이 깨져보이는 것을 볼 수 있다.
(ggplot(petitions)
 + aes('category')
 + geom_bar(fill='green')
)
# Out:
# <ggplot: (8761585334585)>

# %% [markdown]
# ## 시각화를 위해 한글폰트 설치

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

def get_font_family():
    """
    시스템 환경에 따라 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux(colab)
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont

        font_family = "NanumBarunGothic"
    return font_family

plt.rc("font", family=get_font_family())
plt.rc("axes", unicode_minus=False)

# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# #### 한글폰트 사용하기
# * 한글이 깨져보이는 것을 해결하기 위해 한글폰트를 사용해야 한다.
# * 여기에서는 나눔바른고딕을 사용하도록 한다.
#     * 이때 폰트가 로컬 컴퓨터에 설치되어 있어야한다.
#     * 나눔고딕은 무료로 사용할 수 있는 폰트다.
#     * 참고 : [네이버 나눔글꼴 라이선스](https://help.naver.com/support/contents/contents.nhn?serviceNo=1074&categoryNo=3497)
# * 한글을 사용하기 위해서는 ggplot에서 theme에 폰트를 지정해 주면된다.
# * 아래의 문서를 참고하면 **element_text**와 관련된 옵션을 볼 수 있다.
# * 참고 : [plotnine.themes.element_text — plotnine documentation](http://plotnine.readthedocs.io/en/stable/generated/plotnine.themes.element_text.html)

# %%
# 글씨가 겹쳐보이지 않도록 rotation도 추가했다.
(ggplot(petitions)
 + aes('category')
 + geom_bar(fill='green')
 + theme(text=element_text(family='NanumBarunGothic'),
        axis_text_x=element_text(rotation=60))
)
# Out:
# <ggplot: (8761585339597)>

# %% [markdown]
# ### 카테고리별 투표수

# %%
# 다음으로 투표를 많이 받은 카테고리를 알아본다.
# 정치/개혁에 관련된 청원의 숫자가 가장 많았지만 투표를 가장 많이 받은 청원은 인권/성평등이다.
(ggplot(petitions)
 + aes(x='category', y='votes')
 + geom_col(fill='skyblue')
 + theme(text=element_text(family='NanumBarunGothic'),
        axis_text_x=element_text(rotation=70))
)
# Out:
# <ggplot: (8761585416621)>

# %%
# coord_flip을 사용해서 x축과 y축을 바꿔본다.
(ggplot(petitions)
 + aes(x='category', y='votes')
 + geom_col(fill='skyblue')
 + ggtitle('카테고리별 투표수')
 + coord_flip()
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# <ggplot: (8761634695881)>

# %%
(ggplot(petitions) 
 + aes(x='category', y='votes', fill='answer')
 + geom_point()
 + theme(text=element_text(family='NanumBarunGothic'),
        axis_text_x=element_text(rotation=70))
)
# Out:
# <ggplot: (8761634697861)>

# %%
(ggplot(petitions) 
 + aes(x='category', y='votes', fill='answer')
 + geom_boxplot()
 + theme(text=element_text(family='NanumBarunGothic'),
        axis_text_x=element_text(rotation=70))
)
# Out:
# <ggplot: (8761601481857)>

# %%
(ggplot(petitions, aes(x='category', y='votes', fill='answer'))
 + geom_col()
 + theme(text=element_text(family='NanumBarunGothic'),
        axis_text_x=element_text(rotation=70))
)
# Out:
# <ggplot: (8761505064885)>

# %%
# 투표를 가장 많이 받은 카테고리인 인권/성평등에서 투표수가 많은 순으로 보기
human = petitions.loc[(petitions['category']=='인권/성평등')]
human.sort_values('votes', ascending=False)[:2]
# Out:
#                 start        end  answered   votes category  \
# article_id
# 230552     2018-05-11 2018-06-10         1  419006   인권/성평등
# 426834     2018-10-31 2018-11-30         0  416093   인권/성평등
#
#                                                         title  \
# article_id
# 230552                 여성도 대한민국 국민입니다. 성별 관계없는 국가의 보호를 요청합니다.
# 426834      132cm, 31kg의 왜소한 50대 여성이 180cm가 넘는 건장한 20세 남성에...
#
#                                                       content  answer duration
# article_id
# 230552      최근 홍대 누드크로키 모델의 불법촬영 사건이 있었습니다.\n사건은 굉장히 빠르게 처...    True  30 days
# 426834      http://m.news1.kr/articles/?3464603\n관련 기사입니다....    True  30 days

# %% [markdown]
# ## 시계열 변수

# %%
petitions['start_month'] = petitions['start'].dt.month
petitions['start_day'] = petitions['start'].dt.day
petitions.shape
# Out:
# (377756, 11)

# %%
petitions['start_month'].value_counts()
# Out:
# 11    52847
# 9     40888
# 12    38498
# 1     37410
# 10    31687
# 8     28851
# 2     25857
# 7     25714
# 5     25499
# 6     25483
# 4     23227
# 3     21795
# Name: start_month, dtype: int64

# %%
(ggplot(petitions)
 + aes('start_month')
 + geom_bar()
 + ggtitle('시작 월별 청원 수')
 + theme(text=element_text(family='NanumBarunGothic'),  figure_size=(6, 4))
)
# Out:
# <ggplot: (8761611289513)>

# %%
start_df = pd.DataFrame(petitions['start'].value_counts()).reset_index()
start_df.columns = ['start', 'counts']
start_df = start_df.sort_values('start', ascending=True)
print('청원 집계: {}일'.format(start_df.shape[0]))
start_df.head()
# Out:
# 청원 집계: 509일
#          start  counts
# 507 2017-08-19      39
# 500 2017-08-20      88
# 498 2017-08-21      89
# 505 2017-08-22      69
# 502 2017-08-23      80

# %%
(ggplot(start_df)
 + aes(x='start', y='counts')
 + geom_point()
 + geom_line(color='blue')
 + labs(x='날짜', y='청원 수', title='일별 청원 수')
 + theme(text=element_text(family='NanumBarunGothic'),
        figure_size=(18,6))
)
# Out:
# <ggplot: (8761634686185)>

# %%
(ggplot(petitions)
 + aes(x='start', y='votes')
 + geom_point()
 + geom_line(color='blue')
 + labs(x='날짜', y='투표 수', title='일별 투표 수')
 + theme(text=element_text(family='NanumBarunGothic'),
        figure_size=(18,6))
)
# Out:
# <ggplot: (8761601079761)>

# %%
# 일별 투표수
petition_votes = petitions.groupby(['start'])['votes'].sum().reset_index()
petition_votes.columns = ['start', 'votes']
petition_votes.head()
# Out:
#        start  votes
# 0 2017-08-19  20703
# 1 2017-08-20  31710
# 2 2017-08-21   1884
# 3 2017-08-22   2607
# 4 2017-08-23  13446

# %%
(ggplot(petition_votes)
 + aes(x='start', y='votes')
 + geom_point()
 + geom_line(color='blue')
 + labs(x='날짜', y='투표 수', title='일별 투표 수')
 + theme(text=element_text(family='NanumBarunGothic'),
        figure_size=(12,6),
        axis_text_x=element_text(rotation=60))
)
# Out:
# <ggplot: (8761481798581)>

# %%
petition_votes[petition_votes['votes'] > 1000000]
# Out:
#          start    votes
# 424 2018-10-17  1300523

# %%
petitions[(petitions['start'] == '2018-10-17') &
          (petitions['votes'] > 1000000)]
# Out:
#                 start        end  answered    votes category  \
# article_id
# 408609     2018-10-17 2018-11-16         0  1192049    안전/환경
#
#                                     title  \
# article_id
# 408609      강서구 피시방 살인 사건. 또 심신미약 피의자입니다.
#
#                                                       content  answer  \
# article_id
# 408609      2018년 10월 14일 엊그제 일어난 강서구 피시방 살인사건에 대한 청원입니다.\...    True
#
#            duration  start_month  start_day
# article_id
# 408609      30 days           10         17

# %% [markdown]
# ## 청원이 많이 등록된 날
# - 3천건 이상 청원이 등록된 날 어떤 청원이 있는지 본다.

# %%
# 청원이 3000 건이 넘는 날이 있다.
start_df.loc[start_df['counts'] > 3000]
# Out:
#        start  counts
# 1 2017-09-05    5952
# 0 2017-11-11    9623
# 2 2018-01-11    3368

# %%
petitions_20170905 = petitions.loc[petitions['start'] == '2017-09-05']
petitions_20170905.head()
# Out:
#                 start        end  answered  votes category              title  \
# article_id
# 3474       2017-09-05 2017-12-04         0      0    안전/환경  소년법 폐지 죄질은 나이가 없다
# 3475       2017-09-05 2017-12-04         0      0   인권/성평등    소년법폐지 제발 부탁드립니다
# 3476       2017-09-05 2017-12-04         0      0   인권/성평등         청소년 보호법 폐지
# 3477       2017-09-05 2017-09-12         0      0       기타        청소년법 폐지해주세요
# 3478       2017-09-05 2017-09-12         0      0       기타        청소년법 폐지해주세요
#
#                                                       content  answer  \
# article_id
# 3474                                소년법 폐지  무서워서 애들을 키울수가 없어요   False
# 3475        대통령님..부산여중생폭행사건 보셨는지요\n정말 아이를 키우고있는 부모로써 너무나 마...   False
# 3476                                               청소년 보호법 폐지   False
# 3477                         폐지해주세요 아이낳고 키우는게 이나라에선 너무 무섭습니다.   False
# 3478                         폐지해주세요 아이낳고 키우는게 이나라에선 너무 무섭습니다.   False
#
#            duration  start_month  start_day
# article_id
# 3474        90 days            9          5
# 3475        90 days            9          5
# 3476        90 days            9          5
# 3477         7 days            9          5
# 3478         7 days            9          5

# %%
petitions_20170905['category'].value_counts()
# Out:
# 인권/성평등         2202
# 육아/교육          1105
# 안전/환경           880
# 기타              697
# 미래              436
# 정치개혁            319
# 행정              121
# 보건복지             41
# 외교/통일/국방         40
# 교통/건축/국토         25
# 일자리              25
# 성장동력             20
# 문화/예술/체육/언론      13
# 저출산/고령화대책        10
# 경제민주화             9
# 반려동물              7
# 농산어촌              2
# Name: category, dtype: int64

# %%
(ggplot(petitions_20170905)
 + aes(x='category', y='votes')
 + geom_col(fill='skyblue')
 + ggtitle('카테고리별 투표수')
 + coord_flip()
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# <ggplot: (8761492270285)>

# %% [markdown]
# ## 정치개혁 분야의 청원이 많이 들어 온 날의 청원 내용보기
# - 하지만 투표를 가장 많이 받은 청원은 보건/복지 분야의 청원이다.

# %%
petitions_20171111 = petitions.loc[petitions['start'] == '2017-11-11']
petitions_20171111.head()
# Out:
#                 start        end  answered  votes category       title  \
# article_id
# 31383      2017-11-11 2017-12-11         0      1     정치개혁    이명박 출국금지
# 31384      2017-11-11 2017-12-11         0      3   인권/성평등   조두순 출소 금지
# 31386      2017-11-11 2017-12-11         0     39     정치개혁    이명박 출국금지
# 31387      2017-11-11 2017-12-11         0      2     정치개혁  이명박출국금지시켜라
# 31388      2017-11-11 2017-12-11         0      1     정치개혁  이명박출국금지시켜라
#
#                               content  answer duration  start_month  start_day
# article_id
# 31383              이명박 출국금지\n조속한 구속수사   False  30 days           11         11
# 31384       조두순의 출소금지 특별법 제정을 촉구 합니다.   False  30 days           11         11
# 31386       정의가 바로 선 나라를 만들기 위해 꼭...!   False  30 days           11         11
# 31387               명박이을출국금지시키고  수사하라   False  30 days           11         11
# 31388               명박이을출국금지시키고  수사하라   False  30 days           11         11

# %%
petitions_20171111['category'].value_counts()
# Out:
# 정치개혁           7961
# 기타              865
# 미래              170
# 인권/성평등          154
# 안전/환경           128
# 외교/통일/국방         61
# 행정               59
# 경제민주화            47
# 육아/교육            46
# 일자리              25
# 반려동물             24
# 보건복지             20
# 문화/예술/체육/언론      19
# 교통/건축/국토         16
# 성장동력             15
# 저출산/고령화대책         7
# 농산어촌              6
# Name: category, dtype: int64

# %% [markdown]
# ## Groupby 메서드 사용하기
#
# https://pandas.pydata.org/pandas-docs/stable/api.html#groupby

# %%
petitions_20171111.groupby(['category'])['votes'].sum()
# Out:
# category
# 경제민주화             25
# 교통/건축/국토         976
# 기타               461
# 농산어촌               6
# 문화/예술/체육/언론     1378
# 미래               132
# 반려동물              22
# 보건복지           58498
# 성장동력               4
# 안전/환경             78
# 외교/통일/국방        1924
# 육아/교육             98
# 인권/성평등         16338
# 일자리               20
# 저출산/고령화대책         10
# 정치개혁            5080
# 행정                24
# Name: votes, dtype: int64

# %% [markdown]
# ## pivot_table 사용하기

# %%
# 각 데이터의 수를 집계했다. 2017년 11월 11일에 가장 많은 청원이 들어 온 것은 정치개혁이다.
# values에 지정해 준 start_month는 데이터의 갯수를 세는 목적으로 사용했다.
petitions_unique = pd.pivot_table(petitions_20171111, 
                                  index=['category'], 
                                  values=['start_month', 'votes'], 
                                  aggfunc=np.sum)
petitions_best = petitions_unique.sort_values(by='votes', ascending=False)
petitions_best
# Out:
#              start_month  votes
# category
# 보건복지                 220  58498
# 인권/성평등              1694  16338
# 정치개혁               87571   5080
# 외교/통일/국방             671   1924
# 문화/예술/체육/언론          209   1378
# 교통/건축/국토             176    976
# 기타                  9515    461
# 미래                  1870    132
# 육아/교육                506     98
# 안전/환경               1408     78
# 경제민주화                517     25
# 행정                   649     24
# 반려동물                 264     22
# 일자리                  275     20
# 저출산/고령화대책             77     10
# 농산어촌                  66      6
# 성장동력                 165      4

# %% [markdown]
# ## 제목과 내용의 길이
# ### 제목과 내용에 들어가는 단어수

# %%
# 단어 수
# %time petitions['title_num_words'] = petitions['title'].apply(lambda x: len(str(x).split()))
# 중복을 제거한 단어 수
# %time petitions['title_num_uniq_words'] = petitions['title'].apply(lambda x: len(set(str(x).split())))
# Out:
# CPU times: user 273 ms, sys: 3.42 ms, total: 276 ms
# Wall time: 275 ms
# CPU times: user 433 ms, sys: 3.87 ms, total: 437 ms
# Wall time: 439 ms

# %%
# 단어 수
# %time petitions['content_num_words'] = petitions['content'].apply(lambda x: len(str(x).split()))
# 중복을 제거한 단어 수
# %time petitions['content_num_uniq_words'] = petitions['content'].apply(lambda x: len(set(str(x).split())))
# Out:
# CPU times: user 2.37 s, sys: 6.34 ms, total: 2.37 s
# Wall time: 2.38 s
# CPU times: user 4.84 s, sys: 9.82 ms, total: 4.85 s
# Wall time: 4.87 s

# %%
petitions.head()
# Out:
#                 start        end  answered  votes category  \
# article_id
# 21         2017-08-19 2017-11-17         0      9    안전/환경
# 22         2017-08-19 2017-11-17         0     17       기타
# 23         2017-08-19 2017-09-03         0      0       미래
# 24         2017-08-19 2017-08-26         0     53      일자리
# 25         2017-08-19 2017-09-03         0      0       미래
#
#                                title  \
# article_id
# 21               스텔라 데이지호에 대한 제안입니다.
# 22                    비리제보처를 만들어주세요.
# 23                          제2의 개성공단
# 24          공공기관 무조건적인 정규직전환을 반대합니다.
# 25                          제2의 개성공단
#
#                                                       content  answer  \
# article_id
# 21          스텔라 데이지호에 대한 제안입니다.\n3월31일 스텔라 데이지호가 침몰하고 5달째가...   False
# 22          현 정부에 국민들이 가장 원하는 것은 부패척결입니다.  우리 사회에 각종 비리들이 ...   False
# 23          만일 하시는 대통령님 및 각 부처 장관님,주무관님들 안녕하세요!!\n전남 목포에서 ...   False
# 24          현정부에서 정규직 일자리를 늘리는 것에 찬성합니다. 그런데 공공기관 비정규직들은 인...   False
# 25          만일 하시는 대통령님 및 각 부처 장관님,주무관님들 안녕하세요!!\n전남 목포에서 ...   False
#
#            duration  start_month  start_day  title_num_words  \
# article_id
# 21          90 days            8         19                4
# 22          90 days            8         19                2
# 23          15 days            8         19                2
# 24           7 days            8         19                4
# 25          15 days            8         19                2
#
#             title_num_uniq_words  content_num_words  content_num_uniq_words
# article_id
# 21                             4                292                     252
# 22                             2                 67                      62
# 23                             2                118                     105
# 24                             4                108                     101
# 25                             2                118                     105

# %%
(ggplot(petitions)
 + aes('title_num_words', 'content_num_words')
 + geom_point(fill='red', color='lightgray', alpha=0.25)
 + ggtitle('제목, 내용 단어 수')
 + coord_flip()
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# <ggplot: (8761601494093)>

# %%
(ggplot(petitions)
 + aes('votes', 'content_num_words')
 + geom_jitter(fill='red', color='lightgray', alpha=0.25)
 + ggtitle('투표수와 내용 단어 수')
 + coord_flip()
 + theme(text=element_text(family='NanumBarunGothic'))
 + scale_fill_gradient(low = 'red', high = 'yellow') 
)
# Out:
# <ggplot: (8761488860801)>

# %% [markdown]
# ## 특정 단어가 들어가는 청원보기

# %%
petitions[petitions["title"].str.contains("가상화폐")].head()
# Out:
#                 start        end  answered  votes category  \
# article_id
# 21327      2017-10-15 2017-11-14         0      3    경제민주화
# 27765      2017-11-08 2017-12-08         0      1    경제민주화
# 42756      2017-11-12 2017-12-12         0   1311       기타
# 47065      2017-11-21 2017-12-21         0      1       행정
# 47231      2017-11-21 2017-12-21         0      3       기타
#
#                                        title  \
# article_id
# 21327                      가상화폐 투기 광풍을 막아주세요
# 27765          가상화폐 투자대행회사의 무분별한 수수료 바로잡아주세요
# 42756                       가상화폐 거래소 빗썸 조사필요
# 47065       비트코인 등 가상화폐의 모니터링 및 위험고지에 힘써주십시오
# 47231          도와주세요  가상화폐거래소 코인원 신고합니다 대통령님
#
#                                                       content  answer  \
# article_id
# 21327       가상화폐 규제 어떻게 해야 하나 ?\n이제 우리 앞에 놓여진 사회적 이슈가 되어\n...   False
# 27765       가상화폐 ico로 대리업무를 대행해주고 5-30% 수수료를 책정하고 계약서나 기타 ...   False
# 42756       현재 많은 사람들의 관심을 받고있는 가상화폐(암호화폐)를 거래하는 거래소들이있습니다...   False
# 47065       그야말로 가상화폐 광풍인듯 싶습니다.\n1년전까지만해도 100만원도 거품이라는 비트...   False
# 47231       가상화폐거래소 코인원 갑질을 신고합니다..\n11월11일 토요일 새벽  4시50분경...   False
#
#            duration  start_month  start_day  title_num_words  \
# article_id
# 21327       30 days           10         15                4
# 27765       30 days           11          8                5
# 42756       30 days           11         12                4
# 47065       30 days           11         21                7
# 47231       30 days           11         21                5
#
#             title_num_uniq_words  content_num_words  content_num_uniq_words
# article_id
# 21327                          4                319                     284
# 27765                          5                 45                      42
# 42756                          4                 40                      38
# 47065                          7                123                     115
# 47231                          5                617                     530

# %%
petitions[petitions["title"].str.contains("돌봄|아이|초등|보육")].head()
# Out:
#                 start        end  answered  votes category  \
# article_id
# 45         2017-08-19 2017-11-17         0      0    육아/교육
# 56         2017-08-19 2017-11-17         0      5     보건복지
# 72         2017-08-20 2017-11-18         0    212    육아/교육
# 278        2017-08-22 2017-09-21         0      6    육아/교육
# 387        2017-08-23 2017-09-22         0   1166    육아/교육
#
#                                                         title  \
# article_id
# 45                                      초등학교 교사 임용 시험 관련 해결방안
# 56          장애아의 상태에 따른 장애아돌봄도우미 정책의 한계에 관하여...읽어주셨으면 하고 글...
# 72          초등학교의 영어회화전문강사를 비롯한 강사들의 무기계약 전환 시도는 교육대학교와 초등...
# 278                                         아이들의 보금자리를 지켜주세요.
# 387            유치원방과후 강사, 유치원 돌봄교사를 무기계약직 정규직으로 전환하는 것에 반대합니다
#
#                                                       content  answer  \
# article_id
# 45          초등학교 교사 임용 시험을 수능 시험 처럼 전국 단위로 실시하고난 후에\n1지망 2...   False
# 56          안녕하세요. 저는 그냥 평범한 대학생이며, 고등학생인 자폐 1급 남동생을 둔 누나입...   False
# 72          초등학교의 영어회화전문강사를 비롯한 강사들의 무기계약 전환 시도는 교육대학교와 초등...   False
# 278         나이가 어린 영아일수록 부모의 손길이 더 필요하다고 생각하는 현직 보육교사입니다. ...   False
# 387         기회는 평등하게, 과정은 공정하게, 결과는 정의롭게~!\n대통령님 안녕하세요. 유치...   False
#
#            duration  start_month  start_day  title_num_words  \
# article_id
# 45          90 days            8         19                6
# 56          90 days            8         19               10
# 72          90 days            8         20               12
# 278         30 days            8         22                3
# 387         30 days            8         23                9
#
#             title_num_uniq_words  content_num_words  content_num_uniq_words
# article_id
# 45                             6                 95                      80
# 56                            10                690                     519
# 72                            12                159                     144
# 278                            3                209                     191
# 387                            9                206                     186
